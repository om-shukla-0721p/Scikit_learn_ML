# %%
from ydata_profiling import ProfileReport
import pandas as pd
titanic_data=pd.read_csv(r"d:\Downloads_ML_aaa\train.csv")
prof=ProfileReport(titanic_data)
prof.to_file(output_file="titanic_basic_info")
# Out:
# ...
# Export report to file:   0%|          | 0/1 [00:00<?, ?it/s]

# %% [markdown]
# ydata profiling is a very powerful tool which does basic EDA for us
