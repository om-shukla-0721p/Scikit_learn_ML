# %%
import pandas as pd
import requests

# %%
response=requests.get("https://api.openweathermap.org/data/2.5/weather?q=London&appid=4fd967e3cee05e16889af2b600aa631f")

data=response.json()

df=pd.json_normalize(data)
# Out:
#                                              weather      base  visibility  \
# 0  [{'id': 803, 'main': 'Clouds', 'description': ...  stations       10000
#
#            dt  timezone       id    name  cod  coord.lon  coord.lat  ...  \
# 0  1786722360      3600  2643743  London  200    -0.1257    51.5085  ...
#
#    main.grnd_level  wind.speed  wind.deg  wind.gust  clouds.all  sys.type  \
# 0             1009        2.68       299       5.36          57         2
#
#     sys.id  sys.country  sys.sunrise  sys.sunset
# 0  2075535           GB   1786682653  1786735586
#
# [1 rows x 27 columns]
