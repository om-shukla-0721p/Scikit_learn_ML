# %% [markdown]
# <p style="color:red">heading</p>

# %%
import pandas as pd

# %%
# df=pd.read_csv(r"d:\Downloads_ML_aaa\transport.csv",
#                sep=";",
#                index_col="num",
#                usecols=["num","age","sexe","sitfam","principal","commun","revenu"],
#                nrows=25,
#                na_values=["-"])
# df
