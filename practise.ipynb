# %% [markdown]
# <p style="color:red">heading</p>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import requests

# url = "..."

# headers = {
# 	...
# }

# response = requests.get(url, headers=headers)

# data=response.json()

# df=pd.DataFrame(data)

# df.to_csv("tile of csv file",index=False)
