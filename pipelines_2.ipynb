# %%
import pickle
import numpy as np

# %%
pipe=pickle.load(open("pipe.pkl","rb"))

# %%
# assuming users input
test_input1=np.array([2,"male",31,0,0,10.5,"s"],dtype=object).reshape(1,7)

# %%
# prediction
pipe.predict(test_input1)
# Out:
# c:\Users\DELL\Documents\Numpy\anuj\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# c:\Users\DELL\Documents\Numpy\anuj\Lib\site-packages\sklearn\utils\validation.py:2827: UserWarning: X does not have valid feature names, but SimpleImputer was fitted with feature names
#   warnings.warn(
# array([0])
