# %% [markdown]
# ## MICE-> Multivariate Imputation by Chained Equation

# %% [markdown]
# #### itervative imputer
# <br> advantage-> quite accraute for MAR[Missing at Random]
# <br> disadvantage -> slow and memory heavy in server
