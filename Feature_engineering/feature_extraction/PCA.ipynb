# %% [markdown]
# ### PCA-> Principle component analysis
# #### helps reducing dimensionality

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### benefits
# #### 1) faster computation because we reduce dimensions
# #### 2) visualization

# %% [markdown]
# ### geo intuition
# #### rotate the axis and just check varince after that
# <br> n(pca)<=numbers of original features

# %% [markdown]
# ### Code example is on kaggle
# #### pc not good enough for heavy data
