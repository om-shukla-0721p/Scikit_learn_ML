# %%
# from sklearn.compose import ColumnTransformer
# transfrom=ColumnTransformer(transformers=[
#                 ("tnfi",SimpleImputer=[col_names]),
#                 ("tnf2",OrdinalEncoder(categories=[name_of_categories],[col_names])),
#                 ("tnf3",OneHotEncoder(sparse=False,drop="first",[col_names]))
#                  ],   remainder="passthrough")
